# %%
print("Hello")
# Out:
# Hello

# %%
name = "Ada"

# %%
print(name)
# Out:
# Ada

# %%
name
# Out:
# 'Ada'

# %%
age = 25
age
# Out:
# 25

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
price = 45.5
is_renewable = True

# %%
type(price)
# Out:
# float

# %%
type(is_renewable)
# Out:
# bool

# %%
demand = 100
supply = 80
gap = demand - supply
gap
# Out:
# 20

# %%
hours = 24
demand_per_hour = 100
total_daily_demand = hours * demand_per_hour
total_daily_demand
# Out:
# 2400

# %%
country = 'Nigeria'
population = 15000000
electricity_price = 150.7
has_grid_access = True or False

# %%
print(country, has_grid_access)
# Out:
# Nigeria True
