# %%
daily_demand = [120, 135, 128, 140, 150]
daily_demand
# Out:
# [120, 135, 128, 140, 150]

# %%
ddemand = 120, 135, 128, 140, 150
ddemand
# Out:
# (120, 135, 128, 140, 150)

# %%
daily_demand[0]
# Out:
# 120

# %%
daily_demand[2]
# Out:
# 128

# %%
daily_demand[-1]
# Out:
# 150

# %%
electricity_prices = [10.4,5.7,4.9,9.3,6.8]

# %%
electricity_prices[0]
# Out:
# 10.4

# %%
electricity_prices[-1]
# Out:
# 6.8

# %%
len(electricity_prices)
# Out:
# 5

# %%
daily_demand[2] = 130
daily_demand
# Out:
# [120, 135, 130, 140, 150]

# %%
daily_demand.append(145)
daily_demand
# Out:
# [120, 135, 130, 140, 150, 145]

# %%
for day in daily_demand:
    print(day)
# Out:
# 120
# 135
# 130
# 140
# 150
# 145

# %%
for day in daily_demand:
    print(day / 1000)
# Out:
# 0.12
# 0.135
# 0.13
# 0.14
# 0.15
# 0.145
